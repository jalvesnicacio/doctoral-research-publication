# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# import seaborn as sns
set_matplotlib_formats('png', 'pdf')

# %%
# %pylab inline
# %cd /home/jalves/code-py/lab-cosine

# sns.set(style="darkgrid")

data = pd.read_excel('similarity.xls', 'data', index_col = 0)
myChart = plt.figure();
# data.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/jalves/code-py/lab-cosine

# %%
bp = data.boxplot(column = ['Similarity score'],
             by='Diagram', 
             figsize=(20,8),
             patch_artist=True, 
             fontsize=15,
             vert=True,
            )

# myChart.savefig("Q1-boxplot.svg", format="svg")

# %%
# plt.savefig("Q1-similarity.svg", format="svg")
# plt.savefig('line_plot.svg')
